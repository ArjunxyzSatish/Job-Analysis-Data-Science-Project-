# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('./jobs_clean.csv')

# %%
df.describe()
# Out:
#        Salary Estimate       Rating      Founded  Company Age    size_simp  \
# count      1940.000000  1940.000000  1412.000000  1412.000000  1667.000000
# mean      55291.837275     3.853031  1971.563739    52.436261     4.506299
# std       18662.984503     0.491367    61.707624    61.707624     2.168569
# min          12.500000     1.000000  1690.000000     1.000000     1.000000
# 25%       45000.000000     3.600000  1965.000000    14.000000     2.000000
# 50%       54088.025121     3.883648  1997.000000    27.000000     5.000000
# 75%       60000.000000     4.100000  2010.000000    59.000000     7.000000
# max      200000.000000     5.000000  2023.000000   334.000000     7.000000
#
#        revenue_simp    Remote_yn    python_yn         r_yn       sas_yn  ...  \
# count    928.000000  1940.000000  1940.000000  1940.000000  1940.000000  ...
# mean       6.285560     0.060825     0.482474     0.045876     0.056186  ...
# std        2.172031     0.239070     0.499822     0.209271     0.230339  ...
# min        1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%        5.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%        7.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%        8.000000     0.000000     1.000000     0.000000     0.000000  ...
# max        9.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#           spark_yn   mongodb_yn     mysql_yn  deeplearning_yn   tableau_yn  \
# count  1940.000000  1940.000000  1940.000000      1940.000000  1940.000000
# mean      0.144330     0.024742     0.022165         0.077835     0.118041
# std       0.351515     0.155379     0.147258         0.267981     0.322740
# min       0.000000     0.000000     0.000000         0.000000     0.000000
# 25%       0.000000     0.000000     0.000000         0.000000     0.000000
# 50%       0.000000     0.000000     0.000000         0.000000     0.000000
# 75%       0.000000     0.000000     0.000000         0.000000     0.000000
# max       1.000000     1.000000     1.000000         1.000000     1.000000
#
#         powerbi_yn     excel_yn       aws_yn     azure_yn  googlecloud_yn
# count  1940.000000  1940.000000  1940.000000  1940.000000     1940.000000
# mean      0.165464     0.077835     0.226804     0.189175        0.078351
# std       0.371695     0.267981     0.418873     0.391749        0.268792
# min       0.000000     0.000000     0.000000     0.000000        0.000000
# 25%       0.000000     0.000000     0.000000     0.000000        0.000000
# 50%       0.000000     0.000000     0.000000     0.000000        0.000000
# 75%       0.000000     0.000000     0.000000     0.000000        0.000000
# max       1.000000     1.000000     1.000000     1.000000        1.000000
#
# [8 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1940 entries, 0 to 1939
# Data columns (total 40 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job Title        1940 non-null   object
#  1   Company Name     1940 non-null   object
#  2   Salary Estimate  1940 non-null   float64
#  3   Rating           1940 non-null   float64
#  4   Job Description  1905 non-null   object
#  5   Skills           1104 non-null   object
#  6   Location         1940 non-null   object
#  7   Founded          1412 non-null   float64
#  8   Industry         1558 non-null   object
#  9   Sector           1559 non-null   object
#  10  Revenue          1815 non-null   object
#  11  Size             1812 non-null   object
#  12  Ownership Type   1812 non-null   object
#  13  Region           1940 non-null   object
#  14  Company Age      1412 non-null   float64
#  15  Title_Simp       1398 non-null   object
#  16  Seniority        607 non-null    object
#  17  size_simp        1667 non-null   float64
#  18  revenue_simp     928 non-null    float64
#  19  Remote_yn        1940 non-null   int64
#  20  python_yn        1940 non-null   int64
#  21  r_yn             1940 non-null   int64
#  22  sas_yn           1940 non-null   int64
#  23  sql_yn           1940 non-null   int64
#  24  altair_yn        1940 non-null   int64
#  25  talend_yn        1940 non-null   int64
#  26  alteryx_yn       1940 non-null   int64
#  27  pytorch_yn       1940 non-null   int64
#  28  tensorflow_yn    1940 non-null   int64
#  29  scikit-learn_yn  1940 non-null   int64
#  30  spark_yn         1940 non-null   int64
#  31  mongodb_yn       1940 non-null   int64
#  32  mysql_yn         1940 non-null   int64
#  33  deeplearning_yn  1940 non-null   int64
#  34  tableau_yn       1940 non-null   int64
#  35  powerbi_yn       1940 non-null   int64
#  36  excel_yn         1940 non-null   int64
#  37  aws_yn           1940 non-null   int64
#  38  azure_yn         1940 non-null   int64
#  39  googlecloud_yn   1940 non-null   int64
# dtypes: float64(6), int64(21), object(13)
# memory usage: 606.4+ KB

# %%
plt.figure(figsize = (5,3))
plt.hist(df['Salary Estimate'], bins=10, color = '#403d58')
plt.title('Distribution of Salary Estimates')
plt.xlabel('Salary Estimate')
plt.ylabel('Frequency')
plt.ylim((0,1200))
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (5,3))
plt.hist(df['Company Age'], bins=10, color = '#403d58')
plt.title('Distribution of Company Ages')
plt.xlabel('Age')
plt.ylim((0,900))
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (5,3))
plt.hist(df['Rating'], bins=10, color = '#403d58')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.ylim((0,750))
plt.show()

# %%
plt.figure(figsize = (5,3))
df.Seniority.value_counts().plot(kind = 'bar', color='#403d58')
plt.title('Seniority Level Counts')
plt.xlabel('Seniority')
plt.ylim((0,600))
plt.ylabel('Frequency')
plt.xticks(rotation = 0)
plt.show()

# %%
plt.figure(figsize = (5, 3))
df.Title_Simp.value_counts().plot(kind = 'bar', color = '#403d58')
plt.xticks(rotation = 45)
plt.title('Counts of Job Roles')
plt.xlabel('Job Role')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (5, 3))
df.Remote_yn.value_counts().plot(kind = 'bar', color = '#403d58')
plt.xticks(rotation = 0)
plt.title('Counts of Remote Jobs')
plt.xlabel('Remote (Yes/No)')
plt.ylim((0,2000))
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (5,3))
df.Location.value_counts().head(10).plot(kind='bar', color = '#403d58')
plt.title('Counts of Job Locations')
plt.xlabel('Location')
plt.ylabel('Frequency')
plt.ylim((0,1000))
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (5,3))
df.Sector.value_counts().head(10).plot(kind='bar', color = '#403d58')
plt.title('Counts of Job Sectors')
plt.xlabel('Sector')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (5,3))
df.Industry.value_counts().head(10).plot(kind='bar', color = '#403d58')
plt.title('Counts of Job Industries')
plt.xlabel('Industry')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (5,3))
Rev_df = df[df.Revenue.str.contains('USD', na = False)]
Rev_df.Revenue.value_counts().head(10).plot(kind='bar', color = '#403d58')
plt.title('Counts of Company Revenues')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (5,3))
size_df = df[df.Size.str.contains('employees', case = False, na = False)]
size_df.Size.value_counts().head(10).plot(kind='bar', color = '#403d58')
plt.title('Counts of Company Sizes')
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (5,3))
own_df = df[~df['Ownership Type'].str.contains('Unknown', na = False)]
own_df['Ownership Type'].value_counts().head(10).plot(kind='bar', color = '#403d58')
plt.title('Counts of Company Ownership Types')
plt.xlabel('Ownership')
plt.ylabel('Frequency')
plt.show()

# %%
corr = df[['Salary Estimate', 'Rating', 'revenue_simp', 'size_simp', 'Company Age', 'Remote_yn',
       'python_yn', 'r_yn', 'sql_yn', 'pytorch_yn', 'tensorflow_yn', 'scikit-learn_yn',
       'spark_yn', 'deeplearning_yn', 'tableau_yn','powerbi_yn', 'excel_yn', 'aws_yn', 'azure_yn', 'googlecloud_yn']].corr()

# %%
plt.figure(figsize = (10, 6))
sns.heatmap(corr, cmap = 'crest')
plt.title('Corplot between Rating, Revenue, Size and Age of Companies')
plt.show()

# %%
skill_counts = df[['python_yn', 'r_yn', 'sas_yn', 'sql_yn', 'altair_yn', 'talend_yn',
       'alteryx_yn', 'pytorch_yn', 'tensorflow_yn', 'scikit-learn_yn',
       'spark_yn', 'mongodb_yn', 'mysql_yn', 'deeplearning_yn', 'tableau_yn', 'powerbi_yn', 
       'excel_yn', 'aws_yn', 'azure_yn', 'googlecloud_yn']].sum().sort_values(ascending = False)
skill_counts
plt.bar(skill_counts.index, skill_counts.values, color = '#403d58')
plt.xticks(rotation=90)
plt.title('Most In-Demand Data Science Skills')
plt.xlabel('Skill')
plt.ylabel('Counts')
plt.ylim(0, 1000)
plt.show()

# %%
sal_job = pd.pivot_table(df, index = ['Title_Simp'], columns = ['Seniority'], values = 'Salary Estimate', aggfunc='mean').sort_values('senior', ascending = False)
sal_job.plot(kind = 'bar')
plt.xticks(rotation = 45)
plt.xlabel('Job Role')
plt.ylabel('Average Salary')
plt.title('Average Salaries per Job Role')
plt.show()

# %%
df.query('Title_Simp == "Manager" and Seniority == "junior" and Title_Simp.notna() and Seniority.notna()').sort_values('Salary Estimate', ascending=False)
# Out:
#                                              Job Title Company Name  \
# 489  Junior Product Analytics Manager, Parameta Sol...      TP ICAP
#
#      Salary Estimate  Rating  \
# 489         122000.0     3.4
#
#                                        Job Description  \
# 489  The TP ICAP Group is a world leading provider ...
#
#                                                 Skills Location  Founded  \
# 489  SQL, Data science, Quantitative analysis, Comm...   London   2016.0
#
#                           Industry   Sector  ... spark_yn mongodb_yn mysql_yn  \
# 489  Investment & Asset Management  Finance  ...        0          0        0
#
#     deeplearning_yn  tableau_yn powerbi_yn excel_yn  aws_yn  azure_yn  \
# 489               0           0          0        0       0         0
#
#      googlecloud_yn
# 489               0
#
# [1 rows x 40 columns]

# %%
top_sect = df.Sector.value_counts().head(10).index
top_sect_df = df[df.Sector.isin(top_sect)]
sal_sect = pd.pivot_table(top_sect_df, index = 'Sector', values = 'Salary Estimate', aggfunc = 'mean').sort_values('Salary Estimate', ascending = False)
sal_sect.plot(kind='bar')
plt.show()

# %%
sect_job = pd.pivot_table(top_sect_df, index = 'Sector', columns = 'Title_Simp', aggfunc = 'size')
ax = sect_job.plot(kind = 'bar')
plt.xticks(rotation = 90)
plt.xlabel('Sector')
plt.ylabel('Count')
plt.title('Job Demands per Sector for Each Role')
ax.legend(title = 'Job Role')
plt.show()

# %%
# have an option in the webapp to input the industry name and have this distribution pop up 
sect_job = pd.pivot_table(df[df['Sector'].str.contains('Media', na = False, case = False)], index = 'Sector', columns = 'Title_Simp', aggfunc = 'size')
ax = sect_job.plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.xlabel('Sector')
plt.ylabel('Count')
plt.title('Job Demands in the Media Sector for Each Role')
ax.legend(title = 'Job Role', loc = 'upper right')
plt.show()

# %%
top_ind = df.Industry.value_counts().head(10).index
top_ind_df = df[df.Industry.isin(top_ind)]
ind_job = pd.pivot_table(top_ind_df, index = 'Industry', columns = 'Title_Simp', aggfunc = 'size')
ax = ind_job.plot(kind = 'bar')
plt.xticks(rotation = 90)
plt.xlabel('Industry')
plt.ylabel('Count')
plt.title('Job Demands per Industry for Each Role')
ax.legend(title = 'Job Role', loc = 'upper left')
plt.show()

# %%
sal_sect = pd.pivot_table(top_ind_df, index = 'Industry', values = 'Salary Estimate', aggfunc = 'mean').sort_values('Salary Estimate', ascending = False)
sal_sect.plot(kind='bar')
plt.show()

# %%
# have an option in the webapp to input the industry name and have this distribution pop up 
ind_job = pd.pivot_table(df[df['Industry'].str.contains('Business consulting', na = False, case = False)], index = 'Industry', columns = 'Title_Simp', aggfunc = 'size')
ax = ind_job.plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.xlabel('Industry')
plt.ylabel('Count')
plt.title('Job Demands in the Business Consulting Industry for Each Role')
ax.legend(title = 'Job Role', loc = 'upper right')
plt.show()

# %%
sal_rem = pd.pivot_table(df, index = 'Remote_yn', values = 'Salary Estimate', aggfunc = 'mean').sort_values('Salary Estimate', ascending = False)
sal_rem.plot(kind='bar')
plt.show()

# %%
df.columns
# Out:
# Index(['Job Title', 'Company Name', 'Salary Estimate', 'Rating',
#        'Job Description', 'Skills', 'Location', 'Founded', 'Industry',
#        'Sector', 'Revenue', 'Size', 'Ownership Type', 'Region', 'Company Age',
#        'Title_Simp', 'Seniority', 'size_simp', 'revenue_simp', 'Remote_yn',
#        'python_yn', 'r_yn', 'sas_yn', 'sql_yn', 'altair_yn', 'talend_yn',
#        'alteryx_yn', 'pytorch_yn', 'tensorflow_yn', 'scikit-learn_yn',
#        'spark_yn', 'mongodb_yn', 'mysql_yn', 'deeplearning_yn', 'tableau_yn',
#        'powerbi_yn', 'excel_yn', 'aws_yn', 'azure_yn', 'googlecloud_yn'],
#       dtype='object')

# %%
skills_sal = df[['Salary Estimate', 'python_yn', 'r_yn', 'sas_yn', 'sql_yn', 'altair_yn', 'talend_yn',
       'alteryx_yn', 'pytorch_yn', 'tensorflow_yn', 'scikit-learn_yn',
       'spark_yn', 'mongodb_yn', 'mysql_yn', 'deeplearning_yn', 'tableau_yn',
       'powerbi_yn', 'excel_yn', 'aws_yn', 'azure_yn', 'googlecloud_yn']]

# %%
sksal = pd.pivot_table(df, index = ['python_yn', 'sql_yn'], values = 'Salary Estimate', aggfunc = 'mean')
sksal
# Out:
#                   Salary Estimate
# python_yn sql_yn
# 0         0          51045.423652
#           1          50430.360255
# 1         0          61380.926042
#           1          59343.704990
